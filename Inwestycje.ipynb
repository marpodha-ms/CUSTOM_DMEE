# %% [markdown]
# <a href="https://colab.research.google.com/github/marpodha-ms/CUSTOM_DMEE/blob/main/Inwestycje.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Library

# %%
# !pip install investpy
# !pip install airflow
# !pip install yfinance pyodbc pandas investpy

import investpy as invest
import pandas as pd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 37.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 16.0 MB/s eta 0:00:00
# ...
#   Created wheel for investpy: filename=investpy-1.0.8-py3-none-any.whl size=4481565 sha256=6b00a1ec02bab52ccde7e40f5bf72da5cb60e02fc29481ad5f1209a9925c7ddf
#   Stored in directory: /root/.cache/pip/wheels/dd/f4/e0/4807b8928ec08b376e1e1f1e1cc597a747cdd8356c37ee618f
# Successfully built investpy
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# ...

# %% [markdown]
# # New Section
